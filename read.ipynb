# %%
import json

# %%
with open('weibo.json', "rb") as fo:
   weibo_data = json.load(fo, encoding='bytes')

# %%
print(len(weibo_data),type(weibo_data))
for key in weibo_data.keys():
    print(key,end=" ")
print()
print(len(weibo_data['热门']),type(weibo_data['热门']))
# Out:
# 8 <class 'dict'>
# 热门 社会 科技 电影 音乐 数码 汽车 游戏
# 36 <class 'list'>

# %%
for i in range(len(weibo_data['热门'])):
    print(weibo_data['热门'][i])
# Out:
# {'event': 'None', 'post': '走吧一起去看故宫日出', 'time': '2023-01-04', 'ip': 18, 'thumbs': 1183, 'comments': [{'content': '摄影渲染翌嘉渲染翌嘉', 'time': '2023-01-04', 'ip': 18, 'thumbs': 31}, {'content': '', 'time': '2023-01-16', 'ip': 10, 'thumbs': 0}, {'content': '去景山憧憬', 'time': '2023-01-11', 'ip': 12, 'thumbs': 0}, {'content': '年后想去看故宫的雪', 'time': '2023-01-06', 'ip': 17, 'thumbs': 0}, {'content': '好看', 'time': '2023-01-05', 'ip': 17, 'thumbs': 0}, {'content': '历史与现代', 'time': '2023-01-05', 'ip': 9, 'thumbs': 0}, {'content': '传统的东西就是好赞', 'time': '2023-01-04', 'ip': 11, 'thumbs': 0}, {'content': '宏大而壮丽心', 'time': '2023-01-04', 'ip': 18, 'thumbs': 0}, {'content': '', 'time': '2023-01-04', 'ip': 6, 'thumbs': 0}, {'content': '故宫美景鸿城', 'time': '2023-01-04', 'ip': 4, 'thumbs': 0}, {'content': '', 'time': '2023-01-04', 'ip': 28, 'thumbs': 0}, {'content': '走起', 'time': '2023-01-19', 'ip': 0, 'thumbs': 0}, {'content': '美', 'time': '2023-01-22', 'ip': 15, 'thumbs': 0}, {'content': '心心', 'time': '2023-01-22',
# ...
